# %% [markdown]
# ### 단변량 그래프 그리기 - 히스토그램

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %% [markdown]
# #### histogram 도수분포표를 그래프로 나타낸 것 보통 x축이 계급이고 y축이 도수이다.

# %%
ax = plt.subplots()
ax = sns.histplot(tips['total_bill'], kde=True)
ax.set_title('Total Bill Histogram with Density Plot''Total Bill Histogram with Density Plot')
ax.set_ylabel('Freuency')
ax.set_xlabel('Total Bill')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 0, 'Total Bill')

# %%
ax = plt.subplots()
ax = sns.kdeplot(tips['total_bill'])
ax.set_title('Total Bill Histogram with Density Plot''Total Bill Histogram with Density Plot')
ax.set_ylabel('Unit Probability')
ax.set_xlabel('Total Bill')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 0, 'Total Bill')

# %% [markdown]
# #### rugplot은 양탄자 그래프라고 하며 그래프의 축에 동일한 길이의 직선을 붙여 데이터의 밀집 정도를 표현한 것이다.

# %%
ax = plt.subplots()
ax = sns.histplot(tips['total_bill'], kde=True)
ax = sns.rugplot(tips['total_bill'])
ax.set_title('Total Bill Histogram with Density Plot''Total Bill Histogram with Density Plot')
ax.set_ylabel('Freuency')
ax.set_xlabel('Total Bill')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 0, 'Total Bill')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
ax = plt.subplots()
ax = sns.countplot('day', data=tips)
ax.set_title('Count of days')
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Frequency')
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Users\rkdtk\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ### 다양한 종류의 이변량 그래프 그리기

# %%
ax = plt.subplots()
# regplot 회귀 선과 함께 산점도 그래프가 그려진다. fit_reg 인자로 회귀선 유무를 결정할 수 있다.
ax = sns.regplot(x='total_bill', y='tip', data=tips)
ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Total_Bill')
ax.set_ylabel('Tip')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Tip')

# %%
ax = plt.subplots()
# regplot 회귀 선과 함께 산점도 그래프가 그려진다. fit_reg 인자로 회귀선 유무를 결정할 수 있다.
ax = sns.regplot(x='total_bill', y='tip', data=tips, fit_reg=False)
ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Total_Bill')
ax.set_ylabel('Tip')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Tip')

# %% [markdown]
# #### jointplot 산점도 그래프와 히스토그래 그래프를 한 번에 그린다.

# %%
joint = sns.jointplot(x='total_bill', y='tip', data=tips)
joint.set_axis_labels(xlabel='Total_Bill', ylabel='Tip')
joint.fig.suptitle('Joint Plot of Total Bill and Tip', fontsize=10, y=1.03) # 제목이 왜 안나오지?
joint.fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
joint = sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex') # 기존 산점도 그래프를 보완하여 가시성을 높임
joint.set_axis_labels(xlabel='Total_Bill', ylabel='Tip')
joint.fig.suptitle('Joint Plot of Total Bill and Tip', fontsize=10, y=1.03) # 제목이 왜 안나오지?
joint.fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# #### 이차원 밀집도 그래프 그리기

# %%
ax = plt.subplots()
ax = sns.kdeplot(x=tips['total_bill'],
                y=tips['tip'],
                shade=True)
ax.set_title('Kernal Density Plot of Total Bill and Tip')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Kernal Density Plot of Total Bill and Tip')

# %% [markdown]
# #### 바 그래프 그리기
# - 지정한 변수의 평균을 계산하여 그림

# %%
ax = plt.subplots()
ax = sns.barplot(x='time', y='total_bill', data=tips)
ax.set_title('Bar plot of average totla bill for time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Average total bill')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Average total bill')

# %% [markdown]
# #### 박스 그래프 그리기
# - 박스 그래프는 최소값, 1분위수, 중간값, 3분위수, 최댓값, 이상치 등 다양한 통계량을 한 번에 표현하는 그래프입니다.

# %%
ax = plt.subplots()
ax = sns.boxplot(x='time', y='total_bill', data=tips)
ax.set_title('Boxplot of total bill by time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Total Bill')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Total Bill')

# %% [markdown]
# #### 바이올린 그래프
# - 박스 그래프에서 데이터 분산이 모호한 것을 대신하는? 그래프

# %%
ax = plt.subplots()
ax = sns.violinplot(x='time', y='total_bill', data=tips)
ax.set_title('Boxplot of total bill by time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Total Bill')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Total Bill')

# %% [markdown]
# #### 관계 그래프 그리기

# %%
fig = sns.pairplot(tips)
# Out:
# <img src="data:image/png;base64,..." width="750">

# %%
pair_grid = sns.PairGrid(tips)
pair_grid = pair_grid.map_upper(sns.regplot)
pair_grid = pair_grid.map_lower(sns.kdeplot)
pair_grid = pair_grid.map_diag(sns.distplot, rug=True)
# pair_grid = pair_grid.map_diag(sns.kdeplot)
# pair_grid = pair_grid.map_diag(sns.histplot)
# pair_grid = pair_grid.map_diag(sns.rugplot)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="750">
# C:\Users\rkdtk\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\rkdtk\anaconda3\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# C:\Users\rkdtk\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\rkdtk\anaconda3\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# C:\Users\rkdtk\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\rkdtk\anaconda3\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### 다변량 그래프 그리기

# %%
ax = plt.subplots()
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', fit_reg=False)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
fig = sns.pairplot(tips, hue='sex')
# Out:
# <img src="data:image/png;base64,..." width="850">

# %%
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex',
                    scatter_kws=s)
# Out:
# <img src="data:image/png;base64,..." width="500">
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24604/4263069465.py in <module>
# ----> 1 scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex',
#       2                     scatter_kws=s)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, facet_kws, size)
#     643         scatter_kws=scatter_kws, line_kws=line_kws,
#     644     )
# --> 645     facets.map_dataframe(regplot, x=x, y=y, **regplot_kws)
#     646     facets.set_axis_labels(x, y)
#     647
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     775
#     776             # Draw the plot
# --> 777             self._facet_plot(func, ax, args, kwargs)
#     778
#     779         # For axis labels, prefer to use positional args for backcompat
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     804             plot_args = []
#     805             plot_kwargs["ax"] = ax
# --> 806         func(*plot_args, **plot_kwargs)
#     807
#     808         # Sort out the supporting information
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     861     scatter_kws["marker"] = marker
#     862     line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 863     plotter.plot(ax, scatter_kws, line_kws)
#     864     return ax
#     865
#
# ~\anaconda3\lib\site-packages\seaborn\regression.py in plot(self, ax, scatter_kws, line_kws)
#     365         # Draw the constituent plots
#     366         if self.scatter:
# --> 367             self.scatterplot(ax, scatter_kws)
#     368
#     369         if self.fit_reg:
#
# ~\anaconda3\lib\site-packages\seaborn\regression.py in scatterplot(self, ax, kws)
#     395
#     396             x, y = self.scatter_data
# --> 397             ax.scatter(x, y, **kws)
#     398         else:
#     399             # TODO abstraction
#
# TypeError: inner() keywords must be strings

# %%
s = dict(tips['size']*10)
s.keys
# Out:
# <function dict.keys>

# %%
for k, v in s.items:
    print(k)
    print(v)
    break
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24604/2875645226.py in <module>
# ----> 1 for k, v in s.items:
#       2     print(k)
#       3     print(v)
#       4     break
#
# TypeError: 'builtin_function_or_method' object is not iterable

# %%
for k, v in s.items:
    print(k)
    print(v)
    break
